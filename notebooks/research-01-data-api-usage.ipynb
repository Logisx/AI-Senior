# %%
from newsapi import NewsApiClient

# %%
# Init
newsapi = NewsApiClient(api_key='47ba1c90e7524e4dada508b8ca021eb3')

# %%
# /v2/everything
all_articles = newsapi.get_everything(q='bitcoin',
                                      language='en',
                                      sort_by='publishedAt',
                                      page_size=100,
                                      page=1)

# %%
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 10401,
#  'articles': [{'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'tokenist.com',
#    'title': 'Bitcoin Spot ETFs Could See $40.4B in Inflows Over First Two Years: Report',
#    'description': 'Based on the relative ratios of the first gold exchange-traded fund (ETF) launched in 2004, VanEck’s analysts predicted spot Bitcoin ETF to witness over $40 billion in inflows over the first two years of trading. Further, the asset manager also forecasted BTC…',
#    'url': 'https://biztoc.com/x/a47886186724b486',
#    'urlToImage': 'https://c.biztoc.com/p/a47886186724b486/s.webp',
#    'publishedAt': '2023-12-08T18:28:07Z',
#    'content': 'Based on the relative ratios of the first gold exchange-traded fund (ETF) launched in 2004, VanEcks analysts predicted spot Bitcoin ETF to witness over $40 billion in inflows over the first two years… [+269 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'stacker.news',
#    'title': "Name a bitcoin conference that doesn't have scoin exposure \\ stacker news ~bitcoin",
#    'description': 'Do pure bitcoin-only conferences exist at all? [2 comments]',
#    'url': 'https://biztoc.com/x/723c4127c7df984c',
#    'urlToImage': 'https://c.biztoc.com/p/723c4127c7df984c/s.webp',
#    'publishedAt': '2023-12-08T18:18:54Z',
#    'content': 'Do pure bitcoin-only conferences exist at all? [2 comments]\r\nThis story appeared on stacker.news, .'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'u.today',
#    'title': 'Price Analysis for December 8',
#    'description': 'Most of the coins keep setting new local peaks, according to CoinStats. The rate of Bitcoin (BTC) has increased by 0.63% since yesterday. On the hourly chart, the price of BTC is looking bullish as the rate is near the local resistance level of $44,039. If th…',
#    'url': 'https://biztoc.com/x/c743b13cfbbfca4b',
#    'urlToImage': 'https://c.biztoc.com/p/c743b13cfbbfca4b/s.webp',
#    'publishedAt': '2023-12-08T18:16:09Z',
#    'content': 'Most of the coins keep setting new local peaks, according to CoinStats.The rate of Bitcoin (BTC) has increased by 0.63% since yesterday.On the hourly chart, the price of BTC is looking bullish as the… [+220 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'newsbtc.com',
#    'title': 'Bitcoin Has Been In A Class Of Its Own For The Last 10 Years, Top Expert Says',
#    'description': 'Bitcoin has encountered a critical resistance level going into the weekend and could move sideways following a massive rally. According to an expert, the cryptocurrency has been breaching every major obstacle, making it one of the best-performing assets. As o…',
#    'url': 'https://biztoc.com/x/be13afff02c4dbc0',
#    'urlToImage': 'https://c.biztoc.com/p/be13afff02c4dbc0/s.webp',
#    'publishedAt': '2023-12-08T18:08:05Z',
#    'content': 'Bitcoin has encountered a critical resistance level going into the weekend and could move sideways following a massive rally. According to an expert, the cryptocurrency has been breaching every major… [+331 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bitcoinist.com',
#    'title': 'Bitcoin HODLing: A Third Of The Supply Now Unmoved Since 5+ Years',
#    'description': 'On-chain data shows about a third of the total circulating Bitcoin supply hasn’t seen any movement on the blockchain since over five years ago. Bitcoin Supply Grows More Dormant As HODLing Continues In a new post on X, analyst James V. Straten shared a chart …',
#    'url': 'https://biztoc.com/x/5c6d049179b04ba0',
#    'urlToImage': 'https://c.biztoc.com/p/5c6d049179b04ba0/s.webp',
#    'publishedAt': '2023-12-08T18:06:14Z',
#    'content': 'On-chain data shows about a third of the total circulating Bitcoin supply hasnt seen any movement on the blockchain since over five years ago.Bitcoin Supply Grows More Dormant As HODLing ContinuesIn … [+241 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'crypto.news',
#    'title': 'Ethereum rising and ETH/BTC outperforms Bitcoin, investors turn to ERC-20 tokens',
#    'description': 'has seen a welcome price bounce over the past week, finally outperforming Bitcoin (BTC) in the ETH/BTC pair after weeks of under-performance. This renewed strength seems driven by positive fundamentals and a broader resurgence in the altcoin market. As such, …',
#    'url': 'https://biztoc.com/x/c88ba3bc44e3dd27',
#    'urlToImage': 'https://c.biztoc.com/p/c88ba3bc44e3dd27/s.webp',
#    'publishedAt': '2023-12-08T18:04:40Z',
#    'content': 'has seen a welcome price bounce over the past week, finally outperforming Bitcoin (BTC) in the ETH/BTC pair after weeks of under-performance.This renewed strength seems driven by positive fundamental… [+257 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptonews.com',
#    'title': 'Bitcoin Price Prediction as Minor Correction Occurs',
#    'description': 'the dominant force in the cryptocurrency market, has impressively held its ground, with its price oscillating around the $43,500 level. This resilience is primarily fueled by a buoyant sentiment pervading the crypto market, drawing on a mix of anticipation an…',
#    'url': 'https://biztoc.com/x/2ff432f2e52a94d1',
#    'urlToImage': 'https://c.biztoc.com/p/2ff432f2e52a94d1/s.webp',
#    'publishedAt': '2023-12-08T18:04:29Z',
#    'content': ', the dominant force in the cryptocurrency market, has impressively held its ground, with its price oscillating around the $43,500 level.This resilience is primarily fueled by a buoyant sentiment per… [+281 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'aol.com',
#    'title': 'El Salvador became the first country to accept Bitcoin as legal tender. Now it’s offering citizenship for a $1 million ‘investment’',
#    'description': 'On Thursday, the government of El Salvador, alongside the stablecoin company Tether, announced a joint initiative called “Adopting El Salvador Freedom” that allows foreigners to obtain a Salvadoran passport in exchange for paying $1 million in Bitcoin. In 202…',
#    'url': 'https://biztoc.com/x/56b843f22cdcf8e6',
#    'urlToImage': 'https://c.biztoc.com/p/56b843f22cdcf8e6/s.webp',
#    'publishedAt': '2023-12-08T18:02:09Z',
#    'content': 'On Thursday, the government of El Salvador, alongside the stablecoin company Tether, announced a joint initiative called Adopting El Salvador Freedom that allows foreigners to obtain a Salvadoran pas… [+289 chars]'},
#   {'source': {'id': None, 'name': 'Bitcoinist'},
#    'author': 'Keshav Verma',
#    'title': 'Bitcoin HODLing: A Third Of The Supply Now Unmoved Since 5+ Years',
#    'description': 'On-chain data shows about a third of the total circulating Bitcoin supply hasn’t seen any movement on the blockchain since over five years ago. Bitcoin Supply Grows More Dormant As HODLing Continues In a new post on X, analyst James V. Straten shared a chart …',
#    'url': 'https://bitcoinist.com/bitcoin-hodling-third-supply-unmoved-since-5-years/',
#    'urlToImage': 'https://bitcoinist.com/wp-content/uploads/2023/12/bastian-riccardi-rEoBwI7hNCU-unsplash.jpg',
#    'publishedAt': '2023-12-08T18:00:49Z',
#    'content': 'On-chain data shows about a third of the total circulating Bitcoin supply hasn’t seen any movement on the blockchain since over five years ago.\r\nBitcoin Supply Grows More Dormant As HODLing Continues… [+3117 chars]'},
#   {'source': {'id': None, 'name': 'newsBTC'},
#    'author': 'Reynaldo Marquez',
#    'title': 'Bitcoin Has Been In A Class Of Its Own For The Last 10 Years, Top Expert Says',
#    'description': 'Bitcoin has encountered a critical resistance level going into the weekend and could move sideways following a massive rally. According to an expert, the cryptocurrency has been breaching every major obstacle, making it one of the best-performing assets. Rela…',
#    'url': 'http://www.newsbtc.com/bitcoin-news/bitcoin-has-been-in-a-class-of-its-own-for-the-last-10-years-top-expert-says/',
#    'urlToImage': 'https://www.newsbtc.com/wp-content/uploads/2023/12/Bitcoin-BTC-BTCUSDT-BTC-chart.jpg?fit=640%2C425',
#    'publishedAt': '2023-12-08T18:00:07Z',
#    'content': 'Bitcoin vs. Gold: The Digital Currency’s Journey to $40,000\r\nJurrien Timmer, Director of Macro for Fidelity, offers insightful analysis of Bitcoin’s trajectory, likening it to “exponential gold.”\r\nHi… [+3021 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptodaily.co.uk',
#    'title': 'Best Move-to-Earn (M2E) Projects Trending Today',
#    'description': "Bitcoin's recent jump to $45,000 on Tuesday, November 5, has sent waves of excitement through the crypto community. This boost comes amid anticipation of potential SEC approvals for several spot BTC ETFs between January 5th and 10th. The clarification of key …",
#    'url': 'https://biztoc.com/x/3ecad0af11c36be5',
#    'urlToImage': 'https://c.biztoc.com/p/3ecad0af11c36be5/s.webp',
#    'publishedAt': '2023-12-08T17:56:10Z',
#    'content': "Bitcoin's recent jump to $45,000 on Tuesday, November 5, has sent waves of excitement through the crypto community. This boost comes amid anticipation of potential SEC approvals for several spot BTC … [+278 chars]"},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'forbes.com',
#    'title': '$1 Million Bitcoin? Companies Preparing For An Institutional Surge',
#    'description': 'Mark Yusko, CEO of Morgan Creek Capital management predicts $300 billion in inflows once a bitcoin ETF is approved by the SEC. "Institutional investors have been cautious about entering the crypto space due to regulatory uncertainties and concerns about custo…',
#    'url': 'https://biztoc.com/x/d9465b591e7fc8e5',
#    'urlToImage': 'https://c.biztoc.com/p/d9465b591e7fc8e5/s.webp',
#    'publishedAt': '2023-12-08T17:50:10Z',
#    'content': 'Mark Yusko, CEO of Morgan Creek Capital management predicts $300 billion in inflows once a bitcoin ETF is approved by the SEC. "Institutional investors have been cautious about entering the crypto sp… [+295 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coingape.com',
#    'title': 'YieldMax Unveils New ETF Focused on MicroStrategy Derivatives',
#    'description': 'In a significant development in the financial sector, YieldMax, a company known for its expertise in exchange-traded funds (ETFs), has officially submitted a filing with the U.S. Securities and Exchange Commission (SEC) for a new yield-bearing ETF. This ETF, …',
#    'url': 'https://biztoc.com/x/83d08dc0ea390206',
#    'urlToImage': 'https://c.biztoc.com/p/83d08dc0ea390206/s.webp',
#    'publishedAt': '2023-12-08T17:50:08Z',
#    'content': 'In a significant development in the financial sector, YieldMax, a company known for its expertise in exchange-traded funds (ETFs), has officially submitted a filing with the U.S. Securities and Excha… [+311 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'nobsbitcoin.com',
#    'title': 'Unconfiscatable Conference 2023',
#    'description': 'The seed funding will support the launch of OCEAN Pool - a non-custodial Bitcoin mining pool where miners are paid directly by the Bitcoin network. The pool also offers complete transparency into its operations, particularly in the areas of block template cre…',
#    'url': 'https://biztoc.com/x/0c0eeadc2df10171',
#    'urlToImage': 'https://c.biztoc.com/p/0c0eeadc2df10171/s.webp',
#    'publishedAt': '2023-12-08T17:49:45Z',
#    'content': 'The seed funding will support the launch of OCEAN Pool - a non-custodial Bitcoin mining pool where miners are paid directly by the Bitcoin network. The pool also offers complete transparency into its… [+144 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'nobsbitcoin.com',
#    'title': "Users of BTCPay Server's LNbank Plugin Urged to Upgrade to v1.8.9 ASAP",
#    'description': 'No Bullshit Bitcoin is funded by our community. LNbank is a BTCPay Server plugin that allows to use its Lightning node as a custodial accounts system with separate Lightning wallets for non-admin users such as individual stores, friends, or family. "I\'ve been…',
#    'url': 'https://biztoc.com/x/d463f7d335a02de4',
#    'urlToImage': 'https://c.biztoc.com/p/d463f7d335a02de4/s.webp',
#    'publishedAt': '2023-12-08T17:49:45Z',
#    'content': 'No Bullshit Bitcoin is funded by our community.LNbank is a BTCPay Server plugin that allows to use its Lightning node as a custodial accounts system with separate Lightning wallets for non-admin user… [+267 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'nobsbitcoin.com',
#    'title': 'Ride The Lightning v0.15.0-beta: CLNRest for Core Lightning',
#    'description': 'No Bullshit Bitcoin is funded by our community. "This is a major integration upgrade and a breaking change for RTL’s integration with Core Lightning." "With this release c-lightning-rest integration has been removed and RTL now uses core lightning’s native CL…',
#    'url': 'https://biztoc.com/x/618503fa73f2b0df',
#    'urlToImage': 'https://c.biztoc.com/p/618503fa73f2b0df/s.webp',
#    'publishedAt': '2023-12-08T17:49:44Z',
#    'content': 'No Bullshit Bitcoin is funded by our community."This is a major integration upgrade and a breaking change for RTLs integration with Core Lightning.""With this release c-lightning-rest integration has… [+268 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'nobsbitcoin.com',
#    'title': 'Payjoin CLI v0.0.1-alpha: A Command-line Payjoin Client for Bitcoin Core',
#    'description': 'No Bullshit Bitcoin is funded by our community. "Exciting news for Payjoin tinkerers! Introducing payjoin-cli alpha - a game-changer for those using Bitcoin Core," announced Dan Gould on Nostr. Payjoin CLI is a command line Payjoin client for bitcoind in rust…',
#    'url': 'https://biztoc.com/x/83b1842e9ac0eb44',
#    'urlToImage': 'https://c.biztoc.com/p/83b1842e9ac0eb44/s.webp',
#    'publishedAt': '2023-12-08T17:49:44Z',
#    'content': 'No Bullshit Bitcoin is funded by our community."Exciting news for Payjoin tinkerers! Introducing payjoin-cli alpha - a game-changer for those using Bitcoin Core," announced Dan Gould on Nostr.Payjoin… [+306 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Mickey Koss, Contributor, \n Mickey Koss, Contributor\n https://www.forbes.com/sites/mikalkoss/',
#    'title': '$1 Million Bitcoin? Companies Preparing For An Institutional Surge',
#    'description': 'Mark Yusko, CEO of Morgan Creek Capital management predicts $300 billion in inflows once a bitcoin ETF is approved by the SEC.',
#    'url': 'https://www.forbes.com/sites/digital-assets/2023/12/08/1-million-bitcoin-companies-preparing-for-an-institutional-surge/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/65296afa9af51d8edb609319/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2023-12-08T17:41:04Z',
#    'content': 'Caitlin Long, founder and chief executive officer of Custodia Bank, speaks during the Bitcoin 2023 ... [+] conference in Miami Beach, Florida, US, on Thursday, May 18, 2023. The three-day conference … [+8010 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bitcoinmagazine.com',
#    'title': 'Defending The Undefendable: The Censoring Miner',
#    'description': 'What do prostitutes, blackmailers, slumlords, and Bitcoin miners who censor transactions all have in common? What if I told you that they are modern-day heroes of the free market economy, bravely providing their economic services despite facing universal scor…',
#    'url': 'https://biztoc.com/x/4cb640cb27203eea',
#    'urlToImage': 'https://c.biztoc.com/p/4cb640cb27203eea/s.webp',
#    'publishedAt': '2023-12-08T17:34:44Z',
#    'content': 'What do prostitutes, blackmailers, slumlords, and Bitcoin miners who censor transactions all have in common? What if I told you that they are modern-day heroes of the free market economy, bravely pro… [+313 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'decrypt.co',
#    'title': 'Novel Wallet Is a Book That Hides Your Bitcoin',
#    'description': '“Tell alpha, egg breeze, of that ingenious wise name travelled far tank wide success he awake crush gas famous unveil of verb.” As opening sentences go, it’s not exactly “Call me Ishmael,” or “It was a bright cold day in April, and the clocks were striking th…',
#    'url': 'https://biztoc.com/x/87c2d601c115e0ae',
#    'urlToImage': 'https://c.biztoc.com/p/87c2d601c115e0ae/s.webp',
#    'publishedAt': '2023-12-08T17:28:08Z',
#    'content': 'Tell alpha, egg breeze, of that ingenious wise name travelled far tank wide success he awake crush gas famous unveil of verb.As opening sentences go, its not exactly Call me Ishmael, or It was a brig… [+273 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'decrypt.co',
#    'title': 'HODL: VanEck Bitcoin ETF Uses Laser-Eyed Lingo for Ticker',
#    'description': 'VanEck, one of the biggest contenders in the Bitcoin ETF race, has revealed it’s staying true to the orange-pilled community by choosing the ticker “HODL” for its potential crypto investment product. In a Friday filing with the Securities and Exchange Commiss…',
#    'url': 'https://biztoc.com/x/87a61ed129316844',
#    'urlToImage': 'https://c.biztoc.com/p/87a61ed129316844/s.webp',
#    'publishedAt': '2023-12-08T17:28:08Z',
#    'content': 'VanEck, one of the biggest contenders in the Bitcoin ETF race, has revealed its staying true to the orange-pilled community by choosing the ticker HODL for its potential crypto investment product.In … [+258 chars]'},
#   {'source': {'id': None, 'name': 'Decrypt'},
#    'author': 'Mathew Di Salvo',
#    'title': 'HODL: VanEck Bitcoin ETF Uses Laser-Eyed Lingo for Ticker',
#    'description': 'The fund manager is one of the biggest contenders in the spot Bitcoin ETF race.',
#    'url': 'https://decrypt.co/209094/hodl-vaneck-bitcoin-etf-uses-laser-eyed-lingo-for-ticker',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2023/12/bitcoin-btc-coin-glowing-orange-gID_7.jpg',
#    'publishedAt': '2023-12-08T17:26:06Z',
#    'content': 'VanEck, one of the biggest contenders in the Bitcoin ETF race, has revealed its staying true to the orange-pilled community by choosing the ticker HODL for its potential crypto investment product.\r\nI… [+1934 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coinpedia.org',
#    'title': 'GMX Sees Surge In Active User Base; Bitcoin Whales Eye New AI Altcoin',
#    'description': 'The post GMX Sees Surge In Active User Base; Bitcoin Whales Eye New AI Altcoin appeared first on Coinpedia Fintech News GMX (GMX), a decentralized crypto exchange (DEX) that offers low fees, recorded an uptick in user activity. However, investors remain skept…',
#    'url': 'https://biztoc.com/x/4968b380a05f830d',
#    'urlToImage': 'https://c.biztoc.com/p/4968b380a05f830d/s.webp',
#    'publishedAt': '2023-12-08T17:20:44Z',
#    'content': 'The post GMX Sees Surge In Active User Base; Bitcoin Whales Eye New AI Altcoin appeared first on Coinpedia Fintech NewsGMX (GMX), a decentralized crypto exchange (DEX) that offers low fees, recorded … [+267 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bitcoinmagazine.com',
#    'title': 'Cash App Releases Its First Ever Bitcoin Focused Magazine',
#    'description': 'In an era desperate for financial literacy, Cash App has taken a “kneaded” step with the launch of "BREAD," a free zine that fuses financial education with culture. The inaugural issue, aptly titled the "Bitcoin Issue," promises to demystify the world and cul…',
#    'url': 'https://biztoc.com/x/161bf4bc942f567d',
#    'urlToImage': 'https://c.biztoc.com/p/161bf4bc942f567d/s.webp',
#    'publishedAt': '2023-12-08T17:20:42Z',
#    'content': 'In an era desperate for financial literacy, Cash App has taken a kneaded step with the launch of "BREAD," a free zine that fuses financial education with culture. The inaugural issue, aptly titled th… [+281 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'investorplace.com',
#    'title': 'Cardano Price Predictions: Where Will the ADA Crypto Go in 2024?',
#    'description': 'Cardano (ADA-USD) price predictions are a hot topic among crypto traders on Friday as they feel the effects of a broader rally for the market. The big news that has cryptos rising today concerns Bitcoin (BTC-USD). The largest crypto is reportedly getting an E…',
#    'url': 'https://biztoc.com/x/58043adcf2bf1234',
#    'urlToImage': 'https://c.biztoc.com/p/58043adcf2bf1234/s.webp',
#    'publishedAt': '2023-12-08T17:20:31Z',
#    'content': 'Cardano (ADA-USD) price predictions are a hot topic among crypto traders on Friday as they feel the effects of a broader rally for the market.The big news that has cryptos rising today concerns Bitco… [+294 chars]'},
#   {'source': {'id': None, 'name': 'Decrypt'},
#    'author': 'Stephen Graves',
#    'title': 'Novel Wallet Is a Book That Hides Your Bitcoin',
#    'description': 'This low-tech tome puts every possible passphrase word in print, providing a creative way to safely store your seed phrase.',
#    'url': 'https://decrypt.co/209113/novel-wallet-is-a-book-that-hides-your-bitcoin',
#    'urlToImage': 'https://cdn.decrypt.co/resize/1024/height/512/wp-content/uploads/2023/12/bip39book-gID_7.jpeg',
#    'publishedAt': '2023-12-08T17:16:02Z',
#    'content': 'Tell alpha, egg breeze, of that ingenious wise name travelled far tank wide success he awake crush gas famous unveil of verb.\r\nAs opening sentences go, its not exactly Call me Ishmael, or It was a br… [+2159 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'beincrypto.com',
#    'title': 'Ethereum Sets Sights on $3,000 as ETH Bulls Take Control. Bitcoin Minetrix Presale Tops $5 Million',
#    'description': 'price is on the rise again, continuing the altcoin’s strong performance over the past couple months. After trading near $1,500 in mid-October, ETH now sits around $2,385, representing a gain of nearly 60% in under two months. Analysts have turned increasingly…',
#    'url': 'https://biztoc.com/x/e494d7fcc80ffa15',
#    'urlToImage': 'https://c.biztoc.com/p/e494d7fcc80ffa15/s.webp',
#    'publishedAt': '2023-12-08T17:14:39Z',
#    'content': 'price is on the rise again, continuing the altcoins strong performance over the past couple months. After trading near $1,500 in mid-October, ETH now sits around $2,385, representing a gain of nearly… [+322 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coingape.com',
#    'title': 'Ethereum Price Prediction As Open Interest Hits $8B, $3,500 Coming In December?',
#    'description': 'Ethereum Price Prediction: Investor interest has continued to grow both in the spot and derivatives market. Ethereum (ETH) and Bitcoin (BTC) alongside other major cryptocurrencies Solana (ADA) and Cardano (ADA) consistently posted new 2023 highs. There is eno…',
#    'url': 'https://biztoc.com/x/8ccb6c2e1213fbd8',
#    'urlToImage': 'https://c.biztoc.com/p/8ccb6c2e1213fbd8/s.webp',
#    'publishedAt': '2023-12-08T17:08:07Z',
#    'content': 'Ethereum Price Prediction: Investor interest has continued to grow both in the spot and derivatives market. Ethereum (ETH) and Bitcoin (BTC) alongside other major cryptocurrencies Solana (ADA) and Ca… [+266 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'dlnews.com',
#    'title': 'El Salvador offers citizenship to those with $1m Bitcoin or Tether',
#    'description': 'El Salvador continues to expand its Bitcoin-friendly initiatives, with its own Bitcoin investments now worth $120 million. The Central American country, with stablecoin issuer Tether’s support, has launched a visa programme that can also grant citizenship thr…',
#    'url': 'https://biztoc.com/x/58901c711cbc5b88',
#    'urlToImage': 'https://c.biztoc.com/p/58901c711cbc5b88/s.webp',
#    'publishedAt': '2023-12-08T17:06:38Z',
#    'content': 'El Salvador continues to expand its Bitcoin-friendly initiatives, with its own Bitcoin investments now worth $120 million.The Central American country, with stablecoin issuer Tethers support, has lau… [+295 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'crypto.news',
#    'title': 'Fidelity spot Bitcoin ETF listed on DTCC',
#    'description': 'Fidelity’s Wise Origin spot Bitcoin ETF is listed on the Depository Trust & Clearing Corporation (DTCC) under the ticker symbol FBTC. The spot Bitcoin ETF was listed by DTCC, which is engaged in clearing transactions. It provides post-trade clearance, settlem…',
#    'url': 'https://biztoc.com/x/9e2091d0b32ae16c',
#    'urlToImage': 'https://c.biztoc.com/p/9e2091d0b32ae16c/s.webp',
#    'publishedAt': '2023-12-08T17:04:08Z',
#    'content': 'Fidelitys Wise Origin spot Bitcoin ETF is listed on the Depository Trust &amp; Clearing Corporation (DTCC) under the ticker symbol FBTC.The spot Bitcoin ETF was listed by DTCC, which is engaged in cl… [+329 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'theblock.co',
#    'title': 'Bitcoin’s price rises with stocks as Wall Street assesses US jobs data',
#    'description': "Bitcoin rises after U.S. jobs data bolsters hopes the Federal Reserve might achieve a 'soft landing' for the nation's economy. #federalreserve",
#    'url': 'https://biztoc.com/x/49cd11ba86551518',
#    'urlToImage': 'https://c.biztoc.com/p/49cd11ba86551518/s.webp',
#    'publishedAt': '2023-12-08T17:00:49Z',
#    'content': 'Bitcoin rises after U.S. jobs data bolsters hopes the Federal Reserve might achieve a "soft landing" for the nation\'s economy.\r\n#federalreserve\r\nThis story appeared on theblock.co, .'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptopotato.com',
#    'title': 'Bitcoin Explodes to $44K, Ordinals and BRC20 Tokens Surge, Meme Coin Madness Accelerates: This Week’s Recap',
#    'description': 'The past week was particularly explosive in the crypto markets, the capitalization of which increased by close to $200 billion. Currently standing at $1.7 trillion, the industry shows little signs of slowing down. Starting with Bitcoin, its price exploded by …',
#    'url': 'https://biztoc.com/x/7718f272be64c7a0',
#    'urlToImage': 'https://c.biztoc.com/p/7718f272be64c7a0/s.webp',
#    'publishedAt': '2023-12-08T16:56:12Z',
#    'content': 'The past week was particularly explosive in the crypto markets, the capitalization of which increased by close to $200 billion. Currently standing at $1.7 trillion, the industry shows little signs of… [+278 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'CleanSpark (NASDAQ:CLSK) Trading Up 4.2%',
#    'description': 'CleanSpark, Inc. (NASDAQ:CLSK – Get Free Report) shares were up 4.2% on Friday . The stock traded as high as $9.76 and last traded at $9.63. Approximately 5,266,347 shares traded hands during trading, a decline of 49% from the average daily volume of 10,310,6…',
#    'url': 'https://www.etfdailynews.com/2023/12/08/cleanspark-nasdaqclsk-trading-up-4-2/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/cleanspark-inc-logo.png?v=20221221113123&w=240&h=240&zc=2',
#    'publishedAt': '2023-12-08T16:54:50Z',
#    'content': 'CleanSpark, Inc. (NASDAQ:CLSK – Get Free Report) shares were up 4.2% on Friday . The stock traded as high as $9.76 and last traded at $9.63. Approximately 5,266,347 shares traded hands during trading… [+3663 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'Cipher Mining (NASDAQ:CIFR) Shares Up 5%',
#    'description': 'Cipher Mining Inc. (NASDAQ:CIFR – Get Free Report) shares shot up 5% during mid-day trading on Friday . The stock traded as high as $2.77 and last traded at $2.75. 382,229 shares traded hands during mid-day trading, a decline of 77% from the average session v…',
#    'url': 'https://www.etfdailynews.com/2023/12/08/cipher-mining-nasdaqcifr-shares-up-5/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/cipher-mining-inc-logo.png?v=20211202114241&w=240&h=240&zc=2',
#    'publishedAt': '2023-12-08T16:54:42Z',
#    'content': 'Cipher Mining Inc. (NASDAQ:CIFR – Get Free Report) shares shot up 5% during mid-day trading on Friday . The stock traded as high as $2.77 and last traded at $2.75. 382,229 shares traded hands during … [+4345 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptoslate.com',
#    'title': 'VanEck embraces crypto culture with ‘HODL’ ticker for proposed Bitcoin ETF',
#    'description': 'Asset managers Fidelity and VanEck have unveiled their tickers for their spot Bitcoin (BTC) Exchange-Traded Fund (ETF) applications with the U.S. Securities and Exchange Commission (SEC). VanEck chooses HODL VanEck revealed the ticker for its Bitcoin ETF to b…',
#    'url': 'https://biztoc.com/x/1572d2db61e48dc9',
#    'urlToImage': 'https://c.biztoc.com/p/1572d2db61e48dc9/s.webp',
#    'publishedAt': '2023-12-08T16:52:11Z',
#    'content': 'Asset managers Fidelity and VanEck have unveiled their tickers for their spot Bitcoin (BTC) Exchange-Traded Fund (ETF) applications with the U.S. Securities and Exchange Commission (SEC).VanEck choos… [+288 chars]'},
#   {'source': {'id': None, 'name': 'CryptoSlate'},
#    'author': 'Oluwapelumi Adejumo',
#    'title': 'VanEck embraces crypto culture with ‘HODL’ ticker for proposed Bitcoin ETF',
#    'description': 'Asset managers Fidelity and VanEck have unveiled their tickers for their spot Bitcoin (BTC) Exchange-Traded Fund (ETF) applications with the U.S. Securities and Exchange Commission (SEC). VanEck chooses HODL VanEck revealed the ticker for its Bitcoin ETF to b…',
#    'url': 'https://cryptoslate.com/vaneck-embraces-crypto-culture-with-hodl-ticker-for-proposed-bitcoin-etf/',
#    'urlToImage': 'https://cryptoslate.com/wp-content/uploads/2023/12/bitcoin-hodl-vaneck-1.jpg',
#    'publishedAt': '2023-12-08T16:40:54Z',
#    'content': 'Asset managers Fidelity and VanEck have unveiled their tickers for their spot Bitcoin (BTC) Exchange-Traded Fund (ETF) applications with the U.S. Securities and Exchange Commission (SEC).\r\nVanEck cho… [+2896 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'crypto.news',
#    'title': 'BTC rallying, Bitcoin clones could surge in 2024',
#    'description': 'Bitcoin’s (BTC) price has been on a tear in recent months, rising over 62% since mid-October. As the world’s largest cryptocurrency continues its remarkable rally, a new crop of Bitcoin clones and alternatives are emerging that could be poised for massive gro…',
#    'url': 'https://biztoc.com/x/895a454b2dfbbae1',
#    'urlToImage': 'https://c.biztoc.com/p/895a454b2dfbbae1/s.webp',
#    'publishedAt': '2023-12-08T16:38:25Z',
#    'content': 'Bitcoins (BTC) price has been on a tear in recent months, rising over 62% since mid-October. As the worlds largest cryptocurrency continues its remarkable rally, a new crop of Bitcoin clones and alte… [+298 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'thebitcoinbugle.com',
#    'title': 'Triple Elite Memes Losing Members To Swan Sex Cult',
#    'description': 'In a move that is rocking the Bitcoin community, the notorious Meme vigilante group has been thrown into disarray as there appears to be a civil war throwing the group into chaos. A small group of members of the meme gang have been reported to be defecting in…',
#    'url': 'https://biztoc.com/x/7d6f886009e0048c',
#    'urlToImage': 'https://c.biztoc.com/p/7d6f886009e0048c/s.webp',
#    'publishedAt': '2023-12-08T16:38:20Z',
#    'content': 'In a move that is rocking the Bitcoin community, the notorious Meme vigilante group has been thrown into disarray as there appears to be a civil war throwing the group into chaos. A small group of me… [+276 chars]'},
#   {'source': {'id': None, 'name': 'PR Newswire UK'},
#    'author': None,
#    'title': 'OrangeX Unveils $5M Innovation Fund, Accelerating Support for Bitcoin Ecosystem Growth',
#    'description': "VICTORIA, Seychelles, Dec. 8, 2023 /PRNewswire/ -- OrangeX, a global cryptocurrency exchange, is proud to unveil its $5 million Innovation Fund. Designed to bolster the Bitcoin ecosystem and propel blockchain innovation, the Fund's core focus is on investing …",
#    'url': 'https://www.prnewswire.co.uk/news-releases/orangex-unveils-5m-innovation-fund-accelerating-support-for-bitcoin-ecosystem-growth-302010284.html',
#    'urlToImage': None,
#    'publishedAt': '2023-12-08T16:38:00Z',
#    'content': 'VICTORIA, Seychelles, Dec. 8, 2023 /PRNewswire/ -- OrangeX, a global cryptocurrency exchange, is proud to unveil its $5 million Innovation Fund. Designed to bolster the Bitcoin ecosystem and propel b… [+3883 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'u.today',
#    'title': 'Bitcoin, Ethereum Fees Rise in Tandem as On-chain Activity Spikes',
#    'description': "On-chain analytics start-up IntoTheBlock reports an on-chain activity spike thisweek as Bitcoin and other cryptocurrencies rallied to new yearly highs. As a result, the Bitcoin network saw a large increase in transaction fees, surpassing Ethereum's total fees…",
#    'url': 'https://biztoc.com/x/d304da4131aa0615',
#    'urlToImage': 'https://c.biztoc.com/p/d304da4131aa0615/s.webp',
#    'publishedAt': '2023-12-08T16:36:21Z',
#    'content': 'On-chain analytics start-up IntoTheBlock reports an on-chain activity spike thisweek as Bitcoin and other cryptocurrencies rallied to new yearly highs.As a result, the Bitcoin network saw a large inc… [+249 chars]'},
#   {'source': {'id': None, 'name': 'MarketWatch'},
#    'author': 'Philip van Doorn',
#    'title': 'Investors are taking more risk as we near the end of 2023',
#    'description': 'Also, stock picks, Ozempic and behavior, retirement planning, Microsoft and Nvidia, and investing mistakes to avoid.',
#    'url': 'https://www.marketwatch.com/story/investors-are-taking-more-risk-as-we-near-the-end-of-2023-534e8964',
#    'urlToImage': 'https://images.mktw.net/im-44725621/social',
#    'publishedAt': '2023-12-08T16:36:00Z',
#    'content': 'Markets are always moving and their signals are always mixed. Following a dip in October, money has been pouring steadily into the stock market. And in this weeks ETF Wrap, Christine Idzelis looks at… [+6614 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptodaily.co.uk',
#    'title': 'Price Analysis: Modest Gains Following Recent Peak',
#    'description': 'Price Analysis: Modest Gains Following Recent Peak – 9 December 2023 Bitcoin (BTC/USD) sought to maintain modest gains early in the Asian session as the pair continued to orbit the 43781.04 area, an upside price objective associated with buying activity aroun…',
#    'url': 'https://biztoc.com/x/31a89a54e676a31b',
#    'urlToImage': 'https://c.biztoc.com/p/31a89a54e676a31b/s.webp',
#    'publishedAt': '2023-12-08T16:32:12Z',
#    'content': 'Price Analysis: Modest Gains Following Recent Peak 9 December 2023Bitcoin (BTC/USD) sought to maintain modest gains early in the Asian session as the pair continued to orbit the 43781.04 area, an ups… [+312 chars]'},
#   {'source': {'id': None, 'name': 'Investing.com'},
#    'author': 'U.Today',
#    'title': 'Peter Schiff Finally Won Big Bitcoin (BTC) Proponent to His Side',
#    'description': 'Peter Schiff Finally Won Big Bitcoin (BTC) Proponent to His Side',
#    'url': 'https://www.investing.com/news/cryptocurrency-news/peter-schiff-finally-won-big-bitcoin-btc-proponent-to-his-side-3252970',
#    'urlToImage': 'https://i-invdn-com.investing.com/news/LYNXMPEE0A01Z_L.jpg',
#    'publishedAt': '2023-12-08T16:30:43Z',
#    'content': 'U.Today - Two prominent figures, Peter Schiff and Mike Novogratz, recently themselves on the same side of an argument, albeit with contrasting viewpoints. \r\nSchiff, a seasoned economist and gold enth… [+2185 chars]'},
#   {'source': {'id': None, 'name': 'Investing.com'},
#    'author': 'U.Today',
#    'title': "Bitcoin Achieves Groundbreaking Milestone, and It's Not BTC Price",
#    'description': "Bitcoin Achieves Groundbreaking Milestone, and It's Not BTC Price",
#    'url': 'https://www.investing.com/news/cryptocurrency-news/bitcoin-achieves-groundbreaking-milestone-and-its-not-btc-price-3252968',
#    'urlToImage': 'https://i-invdn-com.investing.com/news/LYNXNPEE1P15Z_L.jpg',
#    'publishedAt': '2023-12-08T16:30:33Z',
#    'content': 'U.Today - , the largest cryptocurrency by market capitalization, has achieved a groundbreaking milestone, but not in terms of price.\r\nBitcoin has set a new high in its total number of addresses with … [+1492 chars]'},
#   {'source': {'id': None, 'name': 'Ambcrypto.com'},
#    'author': 'Himalay Patel',
#    'title': "Here's how the Jito airdrop benefited Solana",
#    'description': "Jito airdop caused massive surge in activity on Solana.\n The price of SOL observed a dramatic uptick.\n\nJito, the Solana[SOL]-based DeFi platform, kicked off its anticipated airdrop on 7th DeceThe post Here's how the Jito airdrop benefited Solana appeared firs…",
#    'url': 'https://ambcrypto.com/heres-how-the-jito-airdrop-benefited-solana/',
#    'urlToImage': 'https://statics.ambcrypto.com/wp-content/uploads/2023/12/ambcrypto_Futuristic_city_03a105ed-2078-4f5c-95f1-a60ef1aeb7d9-1000x600.png',
#    'publishedAt': '2023-12-08T16:30:08Z',
#    'content': '<ul><li>Jito airdop caused massive surge in activity on Solana.</li><li>The price of SOL observed a dramatic uptick.</li></ul>Jito, the Solana[SOL]-based DeFi platform, kicked off its anticipated air… [+2700 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'stacker.news',
#    'title': 'Savings \\ stacker news ~bitcoin',
#    'description': "Savings. Think about that word. Savings rescues people from a plight or a pickle. It's preparation for the unknown. It's a way to account for the bad things that may happen. Savings is also a way to prepare for something you do want. It's capital accumulation…",
#    'url': 'https://biztoc.com/x/62655e90da2108a1',
#    'urlToImage': 'https://c.biztoc.com/p/62655e90da2108a1/s.webp',
#    'publishedAt': '2023-12-08T16:24:23Z',
#    'content': "Savings. Think about that word. Savings rescues people from a plight or a pickle. It's preparation for the unknown. It's a way to account for the bad things that may happen. Savings is also a way to … [+235 chars]"},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'stacker.news',
#    'title': 'I have trust issues with hardware wallets. (And so should you.) \\ stacker news ~bitcoin',
#    'description': 'When choosing a hardware wallet (signing device) for your cold storage, it’s really important to find one from a manufacturer that has proven to be trustworthy, and the same goes for the software and the marketing team. You don’t want a setup that collects an…',
#    'url': 'https://biztoc.com/x/17b52531bd60eeb2',
#    'urlToImage': 'https://c.biztoc.com/p/17b52531bd60eeb2/s.webp',
#    'publishedAt': '2023-12-08T16:24:23Z',
#    'content': 'When choosing a hardware wallet (signing device) for your cold storage, its really important to find one from a manufacturer that has proven to be trustworthy, and the same goes for the software and … [+290 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptobriefing.com',
#    'title': 'Fidelity’s spot Bitcoin ETF joins BlackRock on DTCC site',
#    'description': 'Fidelity’s Wise Origin Bitcoin Trust, a proposed spot Bitcoin exchange-traded fund (ETF), has appeared on the Depository Trust and Clearing Corporation’s (DTCC) list of new securities with the ticker FBTC. This comes after BlackRock’s highly anticipated spot …',
#    'url': 'https://biztoc.com/x/33295afc1608f96a',
#    'urlToImage': 'https://c.biztoc.com/p/33295afc1608f96a/s.webp',
#    'publishedAt': '2023-12-08T16:24:21Z',
#    'content': 'Fidelitys Wise Origin Bitcoin Trust, a proposed spot Bitcoin exchange-traded fund (ETF), has appeared on the Depository Trust and Clearing Corporations (DTCC) list of new securities with the ticker F… [+319 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'u.today',
#    'title': "Robinhood Expands BTC, ETH and SOL Trading to EU, Terra's Do Kwon to Face Extradition Nightmare, Ripple Stablecoin Project in Palau Completes 1st Phase:…",
#    'description': "U.Today provides you with an overview of the past day's crypto events with the top three news stories. Robinhood commission-free brokerage firm recently on its blog that it is launching Robinhood Crypto app to all eligible customers in the European Union (EU)…",
#    'url': 'https://biztoc.com/x/c64b7bcca8be4f3e',
#    'urlToImage': 'https://c.biztoc.com/p/c64b7bcca8be4f3e/s.webp',
#    'publishedAt': '2023-12-08T16:22:20Z',
#    'content': "U.Today provides you with an overview of the past day's crypto events with the top three news stories.Robinhood commission-free brokerage firm recently on its blog that it is launching Robinhood Cryp… [+297 chars]"},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'beincrypto.com',
#    'title': 'Price Remains Steady as US Unemployment Rates Fall to 3.7%',
#    'description': 'added 199,000 jobs in the non-agriculture sectors in November. How does a strong job market impact Bitcoin (BTC)? A strong job market is considered bullish for the economy in general. But, it also indicates that the Federal Reserve (Fed) will not cut interest…',
#    'url': 'https://biztoc.com/x/192e1c173001d6e9',
#    'urlToImage': 'https://c.biztoc.com/p/192e1c173001d6e9/s.webp',
#    'publishedAt': '2023-12-08T16:18:14Z',
#    'content': 'added 199,000 jobs in the non-agriculture sectors in November. How does a strong job market impact Bitcoin (BTC)?A strong job market is considered bullish for the economy in general. But, it also ind… [+279 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'theblock.co',
#    'title': 'Recession won’t keep bitcoin from reaching new highs in 2024, VanEck predicts in yearly crypto forecast',
#    'description': 'VanEck expects a U.S. recession to arrive in 2024, but still anticipates spot Bitcoin ETFs and the halving spurring Bitcoin to all-time highs. #vaneck',
#    'url': 'https://biztoc.com/x/a3f615e63dbaf7c1',
#    'urlToImage': 'https://c.biztoc.com/p/a3f615e63dbaf7c1/s.webp',
#    'publishedAt': '2023-12-08T16:16:37Z',
#    'content': 'VanEck expects a U.S. recession to arrive in 2024, but still anticipates spot Bitcoin ETFs and the halving spurring Bitcoin to all-time highs.\r\n#vaneck\r\nThis story appeared on theblock.co, .'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'u.today',
#    'title': 'BTC and ETH Brace for Volatile December as $1.9 Billion Worth of Options Expire Today',
#    'description': 'In a high-stakes culmination of options trading, both Bitcoin (BTC) and Ethereum (ETH) are bracing for a potentially volatile December as a staggering $1.9 billion worth of options are set to expire today. The market anticipation is palpable as traders closel…',
#    'url': 'https://biztoc.com/x/2534176ad25255af',
#    'urlToImage': 'https://c.biztoc.com/p/2534176ad25255af/s.webp',
#    'publishedAt': '2023-12-08T16:08:19Z',
#    'content': 'In a high-stakes culmination of options trading, both Bitcoin (BTC) and Ethereum (ETH) are bracing for a potentially volatile December as a staggering $1.9 billion worth of options are set to expire … [+290 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'bitcoinnews.com',
#    'title': 'Jamie Dimon Would "Close Down" Bitcoin If He Had Government Role',
#    'description': 'Jamie Dimon Bitcoin sentiments stays unchanged, as he stands firm against Bitcoin and digital assets. His repeated criticism of digital assets, as the CEO of JPMorgan Chase, sparks debates, highlighting the tension between his views and the bank’s involvement…',
#    'url': 'https://biztoc.com/x/ecc854781761a28f',
#    'urlToImage': 'https://c.biztoc.com/p/ecc854781761a28f/s.webp',
#    'publishedAt': '2023-12-08T16:08:11Z',
#    'content': 'Jamie Dimon Bitcoin sentiments stays unchanged, as he stands firm against Bitcoin and digital assets. His repeated criticism of digital assets, as the CEO of JPMorgan Chase, sparks debates, highlight… [+299 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptodaily.co.uk',
#    'title': 'Gaming & Retail Dominance vs. Ethereum (ETH) Whale Play: Who Wins?',
#    'description': "The potential introduction of a Bitcoin ETF, exemplified by Fidelity's Wise Origin spot Bitcoin ETF being listed on the Depository Trust & Clearing Corporation (DTCC) under the ticker symbol FBTC, marks a pivotal change in cryptocurrency regulation. This deve…",
#    'url': 'https://biztoc.com/x/0d185a5f67fec8fa',
#    'urlToImage': 'https://c.biztoc.com/p/0d185a5f67fec8fa/s.webp',
#    'publishedAt': '2023-12-08T16:04:11Z',
#    'content': "The potential introduction of a Bitcoin ETF, exemplified by Fidelity's Wise Origin spot Bitcoin ETF being listed on the Depository Trust &amp; Clearing Corporation (DTCC) under the ticker symbol FBTC… [+305 chars]"},
#   {'source': {'id': None, 'name': 'Bitcoinist'},
#    'author': 'Ronaldo Marquez',
#    'title': 'Global Crypto Acceptance: Report Reveals Cryptocurrency Legalized In 119 Countries',
#    'description': 'A recent report by CoinGecko sheds light on the global status of cryptocurrency, highlighting the legalization, regulation, and adoption trends across different countries.\xa0 The report reveals intriguing insights into the widespread acceptance of digital asset…',
#    'url': 'https://bitcoinist.com/crypto-acceptance-report-legalized-119-countries/',
#    'urlToImage': 'https://bitcoinist.com/wp-content/uploads/2023/12/Downloader.la-6571fd59d17d2.jpg',
#    'publishedAt': '2023-12-08T16:00:42Z',
#    'content': 'A recent report by CoinGecko sheds light on the global status of cryptocurrency, highlighting the legalization, regulation, and adoption trends across different countries.\xa0\r\nThe report reveals intrig… [+3757 chars]'},
#   {'source': {'id': None, 'name': 'newsBTC'},
#    'author': 'Scott Matherson',
#    'title': 'XRP Price To Go Parabolic? Crypto Analyst Confirms 1000% Golden Cross Has Returned',
#    'description': 'The XRP price is still underperforming the general crypto market raising concerns among holders. However, it is not all bad for the cryptocurrency which boasts of one of the strongest communities in the sector. As for its price, the optimism toward a recovery…',
#    'url': 'http://www.newsbtc.com/analysis/xrp/xrp-price-parabolic-crypto-1000/',
#    'urlToImage': 'https://www.newsbtc.com/wp-content/uploads/2023/12/XRP-price-1.jpeg?fit=1063%2C607',
#    'publishedAt': '2023-12-08T16:00:39Z',
#    'content': 'The XRP price is still underperforming the general crypto market raising concerns among holders. However, it is not all bad for the cryptocurrency which boasts of one of the strongest communities in … [+2325 chars]'},
#   {'source': {'id': None, 'name': 'Investing.com'},
#    'author': 'U.Today',
#    'title': 'BTC and ETH Brace for Volatile December as $1.9 Billion Worth of Options Expire Today',
#    'description': 'BTC and ETH Brace for Volatile December as $1.9 Billion Worth of Options Expire Today',
#    'url': 'https://www.investing.com/news/cryptocurrency-news/btc-and-eth-brace-for-volatile-december-as-19-billion-worth-of-options-expire-today-3252933',
#    'urlToImage': 'https://i-invdn-com.investing.com/news/LYNXMPED09124_L.jpg',
#    'publishedAt': '2023-12-08T16:00:35Z',
#    'content': 'U.Today - In a high-stakes culmination of options trading, both Bitcoin (BTC) and Ethereum (ETH) are bracing for a potentially volatile December as a staggering $1.9 billion worth of options are set … [+2369 chars]'},
#   {'source': {'id': None, 'name': 'Acm.org'},
#    'author': 'The Wall Street Journal',
#    'title': 'Bitcoin Mining Used More Water Than New York City Last Year',
# ...
#    'content': 'If an approval of a spot Bitcoin exchange-traded fund (ETF) in the US is going to happen, its going to happen soon.ETF research analysts are expecting any potential approval orders to come between Ja… [+307 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'beincrypto.com',
#    'title': 'Switzerland City Lugano Bullish on Crypto, Accepts Bitcoin for Taxes. Everlodge to Incorporate AI Within Ecosystem',
#    'description': 'Switzerland city Lugano has now enabled taxpayers the opportunity to use the Bitcoin (BTC) cryptocurrency to pay for taxes, fines, and all other invoices from the municipality. In a statement published on Dec. 5, Lugano authorities said that individuals and b…',
#    'url': 'https://biztoc.com/x/5ca6741c4d5e5a48',
#    'urlToImage': 'https://c.biztoc.com/p/5ca6741c4d5e5a48/s.webp',
#    'publishedAt': '2023-12-08T15:08:07Z',
#    'content': 'Switzerland city Lugano has now enabled taxpayers the opportunity to use the Bitcoin (BTC) cryptocurrency to pay for taxes, fines, and all other invoices from the municipality. In a statement publish… [+274 chars]'},
#   {'source': {'id': None, 'name': 'newsBTC'},
#    'author': 'Keshav Verma',
#    'title': '63.2% Of PEPE Holders Now In Profit: How This Compares With DOGE, SHIB',
#    'description': 'On-chain data shows 63.2% of all PEPE holders are now holding some profit. Here’s how this compares against DOGE, SHIB, and other memecoins. PEPE Has Recently Woken Up With Fresh Rally And On-Chain Activity According to data from the market intelligence platf…',
#    'url': 'http://www.newsbtc.com/meme-coin/63-2-pepe-holders-profit-compares-doge-shib/',
#    'urlToImage': 'https://www.newsbtc.com/wp-content/uploads/2023/12/shutterstock_2301408373.jpg?fit=5616%2C3744',
#    'publishedAt': '2023-12-08T15:00:44Z',
#    'content': 'On-chain data shows 63.2% of all PEPE holders are now holding some profit. Here’s how this compares against DOGE, SHIB, and other memecoins.\r\nPEPE Has Recently Woken Up With Fresh Rally And On-Chain … [+3054 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Susie Violet Ward, Contributor, \n Susie Violet Ward, Contributor\n https://www.forbes.com/sites/susievioletward/',
#    'title': 'AI And Bitcoin – A Synergy For The Future',
#    'description': 'This union is poised to revolutionize aspects of the internet, from micropayments to AI-driven online economic agents.',
#    'url': 'https://www.forbes.com/sites/digital-assets/2023/12/08/ai-and-bitcoin--a-synergy-for-the-future/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/652fd45138b8170d505fff52/0x0.jpg?format=jpg&crop=3040,2016,x0,y0,safe&height=900&width=1600&fit=bounds',
#    'publishedAt': '2023-12-08T14:59:45Z',
#    'content': 'Photo by Joan Cros/\r\nNurPhoto via Getty Images\r\nThe intersection of BitcoinBTC\r\n and Artificial Intelligence is leading in a new era of digital innovation, particularly highlighted by the integration… [+7546 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coinpedia.org',
#    'title': 'VanEck Filed a Fifth Amendment to Their Spot Bitcoin ETF Application',
#    'description': 'The post VanEck Filed a Fifth Amendment to Their Spot Bitcoin ETF Application appeared first on Coinpedia Fintech News VanEck has recently made its fifth amendment to the S-1 Form with the U.S. Securities and Exchange Commission (SEC), showcasing its persiste…',
#    'url': 'https://biztoc.com/x/4a51fbb1ed0f5f10',
#    'urlToImage': 'https://c.biztoc.com/p/4a51fbb1ed0f5f10/s.webp',
#    'publishedAt': '2023-12-08T14:56:19Z',
#    'content': 'The post VanEck Filed a Fifth Amendment to Their Spot Bitcoin ETF Application appeared first on Coinpedia Fintech NewsVanEck has recently made its fifth amendment to the S-1 Form with the U.S. Securi… [+294 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coinspeaker.com',
#    'title': 'Analysts Believe Bitcoin Begins Early Bull Run and May Hit $50,000 This Month',
#    'description': 'Coinspeaker Analysts Believe Bitcoin Begins Early Bull Run and May Hit $50,000 This Month A Bitcoin analyst has said that Bitcoin (BTC) is already displaying signs of an early bull market, while another predicts $50,000 this month. This means that BTC could e…',
#    'url': 'https://biztoc.com/x/2db397d74a352594',
#    'urlToImage': 'https://c.biztoc.com/p/2db397d74a352594/s.webp',
#    'publishedAt': '2023-12-08T14:54:27Z',
#    'content': 'CoinspeakerAnalysts Believe Bitcoin Begins Early Bull Run and May Hit $50,000 This MonthA Bitcoin analyst has said that Bitcoin (BTC) is already displaying signs of an early bull market, while anothe… [+286 chars]'},
#   {'source': {'id': None, 'name': 'Finbold.com'},
#    'author': 'Vinicius Barbosa',
#    'title': 'Short squeeze alert for December 8: Two cryptocurrencies with potential to skyrocket',
#    'description': 'An altseason is brewing in the cryptocurrency market, with most cryptocurrencies showing bullish signals. Most projects now have a balanced … Continued\nThe post Short squeeze alert for December 8: Two cryptocurrencies with potential to skyrocket appeared firs…',
#    'url': 'https://finbold.com/short-squeeze-alert-for-december-8-two-cryptocurrencies-with-potential-to-skyrocket/',
#    'urlToImage': 'https://finbold.com/app/uploads/2023/12/Short-squeeze-december8.jpg',
#    'publishedAt': '2023-12-08T14:44:26Z',
#    'content': 'An altseason is brewing in the cryptocurrency market, with most cryptocurrencies showing bullish signals. Most projects now have a balanced long/short ratio in the derivative market, which hardens th… [+2154 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cointelegraph.com',
#    'title': 'BRC-20 tokens are presenting new opportunities for Bitcoin',
#    'description': 'While the ossification of Bitcoin’s codebase has brought stability and reliability, it’s made Bitcoin a little… well, boring. Where once the Bitcoin ecosystem formed a hub of innovation and a hive of activity, that momentum has shifted to second- and third-ge…',
#    'url': 'https://biztoc.com/x/a16cc9b3d0f87a68',
#    'urlToImage': 'https://c.biztoc.com/p/a16cc9b3d0f87a68/s.webp',
#    'publishedAt': '2023-12-08T14:44:06Z',
#    'content': 'While the ossification of Bitcoins codebase has brought stability and reliability, its made Bitcoin a little well, boring. Where once the Bitcoin ecosystem formed a hub of innovation and a hive of ac… [+296 chars]'},
#   {'source': {'id': None, 'name': 'Cointelegraph'},
#    'author': 'Cointelegraph by Gracy Chen',
#    'title': 'BRC-20 tokens are presenting new opportunities for Bitcoin',
#    'description': "The possibilities for development on the Bitcoin network are expanding — and the BRC-20 ecosystem's rapidly growing market cap reflects the new opportunities.",
#    'url': 'https://cointelegraph.com/news/brc-20-tokens-presenting-new-opportunities-bitcoin',
#    'urlToImage': 'https://images.cointelegraph.com/cdn-cgi/image/format=auto,onerror=redirect,quality=90,width=1200/https://s3.cointelegraph.com/uploads/2023-12/54204aee-2994-413a-8929-8a8684f06fbe.jpg',
#    'publishedAt': '2023-12-08T14:41:23Z',
#    'content': 'As the first blockchain and cryptocurrency, Bitcoin (BTC) paved the way for everything thats come since: nonfungible tokens (NFTs), smart contracts, tokenization, layer-2 solutions, and all the rest.… [+8055 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'stacker.news',
#    'title': "Fidelity's Bitcoin Spot ETF Has Been LISTED \\ stacker news ~bitcoin",
#    'description': "Fidelity's Bitcoin Spot ETF has been LISTED into the Nasdaq DTCC Clearing Company under the Ticker $FBTC APPROVAL CLOSER THAN EVER 20231208_091322.jpg https://twitter.com/healthy_pockets/status/1733078090438320215?t=Wub8_-wILHT5j1_NXTTbOg&s=19 [3 comments]#fi…",
#    'url': 'https://biztoc.com/x/50af4815cdc06bef',
#    'urlToImage': 'https://c.biztoc.com/p/50af4815cdc06bef/s.webp',
#    'publishedAt': '2023-12-08T14:40:47Z',
#    'content': "Fidelity's Bitcoin Spot ETF has been LISTED into the Nasdaq DTCC Clearing Company under the Ticker $FBTC APPROVAL CLOSER THAN EVER 20231208_091322.jpg https://twitter.com/healthy_pockets/status/17330… [+111 chars]"},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptodaily.co.uk',
#    'title': 'Must-Have Cryptos to Get Before BTC ETF Approval',
#    'description': "Currently, a significant shift is underway in the cryptocurrency market: Ethereum (ETH), Dogecoin (DOGE), Ripple (XRP), Polygon (MATIC) and ScapesMania are emerging as key players. This notable transition coincides with the market's anticipation of the Bitcoi…",
#    'url': 'https://biztoc.com/x/1f65b40c49199686',
#    'urlToImage': 'https://c.biztoc.com/p/1f65b40c49199686/s.webp',
#    'publishedAt': '2023-12-08T14:40:12Z',
#    'content': 'Currently, a significant shift is underway in the cryptocurrency market: Ethereum (ETH), Dogecoin (DOGE), Ripple (XRP), Polygon (MATIC) and ScapesMania are emerging as key players. This notable trans… [+276 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'beincrypto.com',
#    'title': 'BTC Ordinal Meme Token ORDI Pumps 600% in a Month. GFOX Closes in on $600,000',
#    'description': 'The following content does not constitute the opinion of BeInCrypto and should not be construed as financial advice The Securities and Exchange Commission (SEC) has already begun discussing core technical details with spot ETF applicants, and markets have pri…',
#    'url': 'https://biztoc.com/x/9a9eec8c5cbce18e',
#    'urlToImage': 'https://c.biztoc.com/p/9a9eec8c5cbce18e/s.webp',
#    'publishedAt': '2023-12-08T14:40:08Z',
#    'content': 'The following content does not constitute the opinion of BeInCrypto and should not be construed as financial adviceThe Securities and Exchange Commission (SEC) has already begun discussing core techn… [+275 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'beincrypto.com',
#    'title': 'This Analyst Knows When the Bitcoin (BTC) Supercycle Will Begin',
#    'description': 'The emerging euphoria in the cryptocurrency market is attracting the attention of analysts and enthusiasts such as Doctor Profit, who analyze the growth cycles of Bitcoin (BTC) in detail. In his opinion, digital gold goes through five key stages that show the…',
#    'url': 'https://biztoc.com/x/9c88a6a00ca1c6b7',
#    'urlToImage': 'https://c.biztoc.com/p/9c88a6a00ca1c6b7/s.webp',
#    'publishedAt': '2023-12-08T14:40:07Z',
#    'content': 'The emerging euphoria in the cryptocurrency market is attracting the attention of analysts and enthusiasts such as Doctor Profit, who analyze the growth cycles of Bitcoin (BTC) in detail.In his opini… [+279 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coinfeeds.io',
#    'title': "El Salvador Launches Bitcoin 'Freedom Visa': Costs 10x More Than Others",
#    'description': 'The \'Freedom Visa\' offers citizenship for $1M Bitcoin investment, aiming to attract crypto investors and bolster the economy. El Salvador has recently made headlines with the introduction of its "Adopting El Salvador Freedom Visa Program," a unique citizenshi…',
#    'url': 'https://biztoc.com/x/9c432dd2f980a5b9',
#    'urlToImage': 'https://c.biztoc.com/p/9c432dd2f980a5b9/s.webp',
#    'publishedAt': '2023-12-08T14:40:07Z',
#    'content': 'The \'Freedom Visa\' offers citizenship for $1M Bitcoin investment, aiming to attract crypto investors and bolster the economy.El Salvador has recently made headlines with the introduction of its "Adop… [+271 chars]'},
#   {'source': {'id': None, 'name': 'ETF Daily News'},
#    'author': 'MarketBeat News',
#    'title': 'Iris Energy (NASDAQ:IREN) PT Raised to $9.50 at JPMorgan Chase & Co.',
#    'description': 'Iris Energy (NASDAQ:IREN – Get Free Report) had its price objective lifted by JPMorgan Chase & Co. from $9.00 to $9.50 in a research note issued to investors on Friday, Benzinga reports. The firm presently has an “overweight” rating on the stock. JPMorgan Cha…',
#    'url': 'https://www.etfdailynews.com/2023/12/08/iris-energy-nasdaqiren-pt-raised-to-9-50-at-jpmorgan-chase-co/',
#    'urlToImage': 'https://www.americanbankingnews.com/wp-content/timthumb/timthumb.php?src=https://www.marketbeat.com/logos/iris-energy-ltd-logo.png?v=20211207110107&w=240&h=240&zc=2',
#    'publishedAt': '2023-12-08T14:28:41Z',
#    'content': 'Iris Energy (NASDAQ:IREN – Get Free Report) had its price objective lifted by JPMorgan Chase &amp; Co. from $9.00 to $9.50 in a research note issued to investors on Friday, Benzinga reports. The firm… [+2926 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'coinpedia.org',
#    'title': 'Crypto Market Outlook : Insights on Ethereum, Avalanche, Chainlink, and Solana',
#    'description': 'Qadir Ak is the founder of Coinpedia. He has over a decade of experience writing about technology and has been covering the blockchain and cryptocurrency space since 2010. He has also interviewed a few prominent experts within the cryptocurrency space. Crypto…',
#    'url': 'https://biztoc.com/x/ae2cd8f779f2c2ca',
#    'urlToImage': 'https://c.biztoc.com/p/ae2cd8f779f2c2ca/s.webp',
#    'publishedAt': '2023-12-08T14:26:55Z',
#    'content': 'Qadir Ak is the founder of Coinpedia. He has over a decade of experience writing about technology and has been covering the blockchain and cryptocurrency space since 2010. He has also interviewed a f… [+286 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptopotato.com',
#    'title': 'Presale Closes in on $700K Amidst Bitcoin’s Blazing Rally',
#    'description': 'Headlines have been dominated recently by the news that Bitcoin soared past the $43k barrier, after months of consolidating in the $30K region. Crypto is known to be an industry where there’s no shortage of options to diversify a portfolio, regardless of what…',
#    'url': 'https://biztoc.com/x/145fb452c10fb6ba',
#    'urlToImage': 'https://c.biztoc.com/p/145fb452c10fb6ba/s.webp',
#    'publishedAt': '2023-12-08T14:22:17Z',
#    'content': 'Headlines have been dominated recently by the news that Bitcoin soared past the $43k barrier, after months of consolidating in the $30K region.Crypto is known to be an industry where theres no shorta… [+300 chars]'},
#   {'source': {'id': None, 'name': 'Naftemporiki.gr'},
#    'author': 'Αλεξία Σωτηρίου',
#    'title': 'The disadvantages of cryptos for Greek taxpayers',
#    'description': 'The non-recognition by the Tax Administration of cryptocurrencies as a legal means of transactions and the lack of legislative provisions for their tax treatment cause enormous problems for taxpayers.\nThe…\nThe disadvantages of cryptos for Greek taxpayers - Η …',
#    'url': 'https://www.naftemporiki.gr/english/1545328/the-disadvantages-of-cryptos-for-greek-taxpayers/',
#    'urlToImage': 'https://www.naftemporiki.gr/wp-content/uploads/2022/11/cryptocoins.jpg',
#    'publishedAt': '2023-12-08T14:20:34Z',
#    'content': 'The non-recognition by the Tax Administration of cryptocurrencies as a legal means of transactions and the lack of legislative provisions for their tax treatment cause enormous problems for taxpayers… [+993 chars]'},
#   {'source': {'id': None, 'name': 'Biztoc.com'},
#    'author': 'cryptonews.com',
#    'title': 'Dogecoin Price Prediction as DOGE Hits 8 Month Highs',
#    'description': 'the famed meme cryptocurrency, has recently soared to an 8-month high, trading around $0.09782. This remarkable surge, highlighted by a peak at $0.10 on Wednesday, signals a robust bullish momentum in the crypto arena. The rally is underpinned by a favorable …',
#    'url': 'https://biztoc.com/x/15dc5436ba270d44',
#    'urlToImage': 'https://c.biztoc.com/p/15dc5436ba270d44/s.webp',
#    'publishedAt': '2023-12-08T14:18:24Z',
#    'content': ', the famed meme cryptocurrency, has recently soared to an 8-month high, trading around $0.09782. This remarkable surge, highlighted by a peak at $0.10 on Wednesday, signals a robust bullish momentum… [+307 chars]'}]}

# %%
len(all_articles['articles'])
# Out:
# 100

# %%
all_articles['articles'][0]['description']
# Out:
# 'Based on the relative ratios of the first gold exchange-traded fund (ETF) launched in 2004, VanEck’s analysts predicted spot Bitcoin ETF to witness over $40 billion in inflows over the first two years of trading. Further, the asset manager also forecasted BTC…'

# %%
# /v2/everything
new_all_articles = newsapi.get_everything(q='bitcoin',
                                      language='en',
                                      sort_by='publishedAt',
                                      page_size=100,
                                      page=2)
# Out:
# ---------------------------------------------------------------------------
# NewsAPIException                          Traceback (most recent call last)
# Cell In[7], line 2
#       1 # /v2/everything
# ----> 2 new_all_articles = newsapi.get_everything(q='bitcoin',
#       3                                       language='en',
#       4                                       sort_by='publishedAt',
#       5                                       page_size=100,
#       6                                       page=2)
#
# File c:\Users\logis\Logis\Study\Self_Edu\Projects\LLMOps_tech_lead_bot\.venv\Lib\site-packages\newsapi\newsapi_client.py:334, in NewsApiClient.get_everything(self, q, qintitle, sources, domains, exclude_domains, from_param, to, language, sort_by, page, page_size)
#     332 # Check Status of Request
#     333 if r.status_code != requests.codes.ok:
# --> 334     raise NewsAPIException(r.json())
#     336 return r.json()
#
# NewsAPIException: {'status': 'error', 'code': 'maximumResultsReached', 'message': 'You have requested too many results. Developer accounts are limited to a max of 100 results. You are trying to request results 100 to 200. Please upgrade to a paid plan if you need more results.'}

# %%
new_all_articles['articles'][0]
